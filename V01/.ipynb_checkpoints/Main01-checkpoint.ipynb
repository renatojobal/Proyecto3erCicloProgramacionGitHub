# %%
# Standard imports 
from bokeh.io import output_notebook
from bokeh.plotting import figure, output_file, output_notebook, show
import pandas as pd
import numpy as np
output_notebook()


from bokeh.models import ColumnDataSource, HoverTool
from bokeh.sampledata.autompg import autompg_clean as df
from bokeh.transform import factor_cmap

# Abrimos el archivo csv y lo convertimos en un DataFrame
dataFrame01 = pd.read_csv("data/Estimates-of-under-five mortality.csv", sep=";", engine='python')

# Declaramos una paleta de colores
colors01 = ['#EF7A63', '#BFF14A', '#5EB3BB', '#21738C', '#792E9C', '#8C8EC9', '#17A655', '#C4C81C', '#BDBE90', '#DAA37B', 
            '#D9371B', '#5C81EA', '#04F7DA', '#833235', '#437032', '#FFD500', '#B2FF00', '#FF9C00', '#FFD8EE', '#E4D8FF', 
            '#D8DFFF', '#D8FAFF', '#D8FFE2', '#F3FFD8', '#FFE7D8', '#6B6464', '#813C3C']

# Calculamos un total de muertes por año y lo agregamos como una columna al final de dataFrame


generalAverage = {'Averages': []}
# Recorremos cada fila
index = 0
while index <= 35:
    year = 1990.5
    
    sum_ = 0 
    # Recorremos cada columna
    while(year <= 2016.5):
        sum_ += dataFrame01[str(year)][index]      
        year += 1
    average = np.round((sum_ / 28), 2)
    generalAverage['Averages'].append(average)
    
    index += 1
# Obtenemos un diccionario:  {'Averages': [130.34, 147.66, 113.48, 38.53, 82.63, 33.75, 30.82, 7.89, 18.84, 30.08, 5.92, 66.1]}

# Lo agregamos como columna a nuestro dataFrame
dataFrame01['Averages'] = generalAverage['Averages']


# Agrupamos segun el nombre de la region
group = dataFrame01.groupby('Region Name', as_index = False).mean()
group
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#                         Region Name      1990.5      1991.5      1992.5  \
# 0             East Asia and Pacific   57.100000   55.933333   54.466667
# 1   Eastern Europe and Central Asia   46.766667   46.366667   46.300000
# 2       Eastern and Southern Africa  164.266667  162.533333  160.733333
# 3           Europe and Central Asia   31.000000   30.333333   29.833333
# 4       Latin America and Caribbean   55.333333   53.000000   50.633333
# 5      Middle East and North Africa   65.566667   62.733333   60.133333
# 6                     North America   10.966667   10.600000   10.266667
# 7                        South Asia  129.466667  125.733333  122.133333
# 8                Sub-Saharan Africa  180.833333  179.233333  177.666667
# 9           West and Central Africa  198.866667  197.433333  196.033333
# 10                   Western Europe   10.500000   10.033333    9.533333
# 11                            World   93.466667   92.166667   90.933333
#
#         1993.5      1994.5      1995.5      1996.5      1997.5      1998.5  \
# 0    52.800000   51.133333   49.366667   47.600000   45.833333   44.000000
# 1    46.266667   45.900000   45.100000   43.833333   42.266667   40.466667
# 2   159.133333  159.466667  156.333333  152.566667  150.300000  147.366667
# 3    29.333333   28.633333   27.733333   26.666667   25.566667   24.333333
# 4    48.266667   45.933333   43.633333   41.433333   39.266667   37.633333
# 5    57.700000   55.300000   53.000000   50.733333   48.633333   46.566667
# 6     9.866667    9.566667    9.266667    8.966667    8.733333    8.533333
# 7   118.666667  115.133333  111.666667  108.133333  104.566667  100.933333
# 8   176.200000  175.666667  173.066667  170.000000  167.400000  164.166667
# 9   194.633333  193.033333  191.033333  188.633333  185.600000  181.966667
# 10    9.033333    8.500000    7.966667    7.533333    7.066667    6.733333
# 11   89.766667   88.766667   87.366667   85.700000   84.033333   82.200000
#
#        ...          2008.5      2009.5      2010.5      2011.5      2012.5  \
# 0      ...       25.333333   23.300000   22.066667   20.933333   19.833333
# 1      ...       22.300000   21.066667   19.866667   18.866667   17.933333
# 2      ...       92.200000   87.466667   82.833333   78.566667   74.633333
# 3      ...       14.066667   13.466667   12.833333   12.266667   11.733333
# 4      ...       23.133333   22.333333   24.933333   20.766667   20.066667
# 5      ...       30.000000   28.833333   27.900000   27.100000   26.466667
# 6      ...        7.500000    7.333333    7.200000    7.066667    6.900000
# 7      ...       68.533333   65.733333   63.000000   60.366667   57.733333
# 8      ...      110.533333  105.633333  100.933333   96.533333   92.500000
# 9      ...      128.800000  123.666667  118.800000  114.233333  110.033333
# 10     ...        4.766667    4.600000    4.466667    4.333333    4.200000
# 11     ...       56.266667   53.800000   51.800000   49.466667   47.500000
#
#         2013.5      2014.5     2015.5     2016.5    Averages
# 0    18.900000   18.000000  17.233333  16.500000   33.756667
# 1    17.033333   16.200000  15.500000  14.766667   30.080000
# 2    71.066667   67.800000  64.966667  62.533333  113.483333
# 3    11.233333   10.766667  10.300000   9.866667   18.836667
# 4    19.400000   18.766667  18.200000  17.666667   30.816667
# 5    25.900000   25.366667  24.866667  24.433333   38.530000
# 6     6.766667    6.666667   6.533333   6.366667    7.893333
# 7    55.200000   52.733333  50.466667  48.333333   82.630000
# 8    88.800000   85.400000  82.400000  79.633333  130.340000
# 9   106.100000  102.533333  99.200000  96.133333  147.660000
# 10    4.100000    4.033333   3.933333   3.866667    5.920000
# 11   45.700000   44.033333  42.533333  41.200000   66.096667
#
# [12 rows x 29 columns]

# %%
"""
Procedemos a crear las figuras con bokeh
"""
# Out:
# '\nProcedemos a crear las figuras con bokeh\n'

# %%
# la primera figura sera barra
""""
p = figure(title="line", plot_width=300, plot_height=300)
p.line(x=[1, 2, 3, 4, 5], y=[6, 7, 2, 4, 5])

show(p)
"""

x_range = group['Region Name']
y_range = group['Averages']


figure01 = figure(x_range=x_range, plot_height=550, title="Under Five Mortality", toolbar_location=None, tools="")
#  figure01.add_tools(HoverTool(tooltips=[("Region Name:", "@Region Name"), ("Averages", "@Averages")]))
figure01.add_tools(HoverTool(tooltips=[("Region Name:", "Region"), ("Averages", "@Averages")]))
figure01.vbar(x=x_range, top=y_range, width=0.9, line_color=colors01[2], line_width=2, fill_color=colors01[:12])
figure01.y_range.start = 0
figure01.yaxis.axis_label = "Number of children"
figure01.xaxis.axis_label = "Region"
figure01.xaxis.major_label_orientation = 1.2
show(figure01)
# Out:
#   <div class="bk-root" id="fb613170-9d54-4a65-936a-c26cb3cf44c7" data-root-id="1003"></div>

# %%
# Ahora vamos a graficar una linea region por region


group01 = group.drop('Averages', 1)
group01 = group01.drop('Region Name', 1)
group01
x_range = group01.to_dict('split')['columns']

# Lo metemos dentro de un ciclo
index = 0
figure04 = figure(x_range=x_range, plot_width=1000, plot_height=1000)    

while index <= 11:
    title = str(group['Region Name'][index])
    y_range = group01.iloc[index]

    figure01 = figure(x_range=x_range, plot_height=550, title=title, toolbar_location=None, tools="")
    figure01.circle(x=x_range, y=y_range, size=4, fill_color=colors01[10])
    figure01.add_tools(HoverTool())
    figure01.line(x=x_range, y=y_range)
    figure01.y_range.start = 0
    figure01.yaxis.axis_label = "Number of children"
    figure01.xaxis.axis_label = "Year"
    figure01.xaxis.major_label_orientation = 1.2
    

    figure04.circle(x=x_range, y=y_range, size=4, fill_color=colors01[10])
    figure04.add_tools(HoverTool())
    figure04.line(x=x_range, y=y_range, legend=title, line_color=colors01[index])
    figure04.y_range.start = 0
    figure04.yaxis.axis_label = "Number of children"
    figure04.xaxis.axis_label = "Year"
    figure04.xaxis.major_label_orientation = 1.2
    
    
    index+=1
    show(figure01)
# Out:
#   <div class="bk-root" id="9e6c4860-4ec6-4141-8ec0-d4ab81644ce5" data-root-id="21269"></div>
#   <div class="bk-root" id="43c05a32-450b-4882-8cf1-7adb31fa8b1b" data-root-id="21964"></div>
#   <div class="bk-root" id="b30a6f7f-029e-40a8-b808-6af36237d8fa" data-root-id="22671"></div>
#   <div class="bk-root" id="cd6adf93-1296-437f-8f12-495fc9d6a4b6" data-root-id="23391"></div>
#   <div class="bk-root" id="cc95b005-f48f-491e-bebd-6c7971850e7e" data-root-id="24124"></div>
#   <div class="bk-root" id="b191f7f7-5f9b-478d-8a4c-c22107f51eca" data-root-id="24870"></div>
#   <div class="bk-root" id="bbc1d55a-ba81-44a1-85d0-a16b804dae9a" data-root-id="25629"></div>
#   <div class="bk-root" id="4781b64d-0eff-4582-ae2e-73890dba624f" data-root-id="26401"></div>
#   <div class="bk-root" id="3be32f0e-2254-4d75-8616-265bbadff9a5" data-root-id="27186"></div>
#   <div class="bk-root" id="89432b97-5faf-460c-b2fd-c30cb698c8e7" data-root-id="27984"></div>
#   <div class="bk-root" id="ac4ee8a5-4cc8-4330-92c4-9bcaeb7e3caa" data-root-id="28795"></div>
#   <div class="bk-root" id="b7d58124-a51a-4201-a00b-f348df6c9642" data-root-id="29619"></div>

# %%
show(figure04)
# Out:
#   <div class="bk-root" id="b14d9c07-c26b-4120-a28d-58fa2762002f" data-root-id="21235"></div>

# %%
xs_range = []
for i in range(0, 10):
    xs_range.append(x_range)
    
ys_range = []
for i in range(0, 10):
    ys_range.append(group.iloc[i])
group02 = group.drop('Averages', 1)
group02 = group02.drop(group02.index[11])
group02
# Out:
#                         Region Name      1990.5      1991.5      1992.5  \
# 0             East Asia and Pacific   57.100000   55.933333   54.466667
# 1   Eastern Europe and Central Asia   46.766667   46.366667   46.300000
# 2       Eastern and Southern Africa  164.266667  162.533333  160.733333
# 3           Europe and Central Asia   31.000000   30.333333   29.833333
# 4       Latin America and Caribbean   55.333333   53.000000   50.633333
# 5      Middle East and North Africa   65.566667   62.733333   60.133333
# 6                     North America   10.966667   10.600000   10.266667
# 7                        South Asia  129.466667  125.733333  122.133333
# 8                Sub-Saharan Africa  180.833333  179.233333  177.666667
# 9           West and Central Africa  198.866667  197.433333  196.033333
# 10                   Western Europe   10.500000   10.033333    9.533333
#
#         1993.5      1994.5      1995.5      1996.5      1997.5      1998.5  \
# 0    52.800000   51.133333   49.366667   47.600000   45.833333   44.000000
# 1    46.266667   45.900000   45.100000   43.833333   42.266667   40.466667
# 2   159.133333  159.466667  156.333333  152.566667  150.300000  147.366667
# 3    29.333333   28.633333   27.733333   26.666667   25.566667   24.333333
# 4    48.266667   45.933333   43.633333   41.433333   39.266667   37.633333
# 5    57.700000   55.300000   53.000000   50.733333   48.633333   46.566667
# 6     9.866667    9.566667    9.266667    8.966667    8.733333    8.533333
# 7   118.666667  115.133333  111.666667  108.133333  104.566667  100.933333
# 8   176.200000  175.666667  173.066667  170.000000  167.400000  164.166667
# 9   194.633333  193.033333  191.033333  188.633333  185.600000  181.966667
# 10    9.033333    8.500000    7.966667    7.533333    7.066667    6.733333
#
#       ...          2007.5      2008.5      2009.5      2010.5      2011.5  \
# 0     ...       26.133333   25.333333   23.300000   22.066667   20.933333
# 1     ...       23.633333   22.300000   21.066667   19.866667   18.866667
# 2     ...       97.366667   92.200000   87.466667   82.833333   78.566667
# 3     ...       14.766667   14.066667   13.466667   12.833333   12.266667
# 4     ...       24.066667   23.133333   22.333333   24.933333   20.766667
# 5     ...       31.266667   30.000000   28.833333   27.900000   27.100000
# 6     ...        7.600000    7.500000    7.333333    7.200000    7.066667
# 7     ...       71.400000   68.533333   65.733333   63.000000   60.366667
# 8     ...      115.700000  110.533333  105.633333  100.933333   96.533333
# 9     ...      134.133333  128.800000  123.666667  118.800000  114.233333
# 10    ...        4.900000    4.766667    4.600000    4.466667    4.333333
#
#         2012.5      2013.5      2014.5     2015.5     2016.5
# 0    19.833333   18.900000   18.000000  17.233333  16.500000
# 1    17.933333   17.033333   16.200000  15.500000  14.766667
# 2    74.633333   71.066667   67.800000  64.966667  62.533333
# 3    11.733333   11.233333   10.766667  10.300000   9.866667
# 4    20.066667   19.400000   18.766667  18.200000  17.666667
# 5    26.466667   25.900000   25.366667  24.866667  24.433333
# 6     6.900000    6.766667    6.666667   6.533333   6.366667
# 7    57.733333   55.200000   52.733333  50.466667  48.333333
# 8    92.500000   88.800000   85.400000  82.400000  79.633333
# 9   110.033333  106.100000  102.533333  99.200000  96.133333
# 10    4.200000    4.100000    4.033333   3.933333   3.866667
#
# [11 rows x 28 columns]

# %%
source = ColumnDataSource(group02)
legend = []
figure03 = figure(plot_width=1000, plot_height=1000)    
figure03.multi_line(xs=xs_range, ys=ys_range,
            color=colors01[:10])

figure03.x_range.start = 1990.5


show(figure03)
# Out:
#   <div class="bk-root" id="61aa0a5f-a348-4589-8363-c68a5a2e1787" data-root-id="31525"></div>

# %%
# Ahora crearemos un grafico de pastel usando wedge
import math

# %%
# Metodo para obtener el porcentaje de un numero
def getPercentage(total, part):
    return (part*100)/total

def getAngle(percentage):
    return (2*pi*percentage)/(100)

# %%
# Lo metemos dentro de un ciclo
index = 0

# Creamos la figura
figure05 = figure(plot_width=1000, plot_height=1000)    
group03 = group.drop(group.index[11])

total = group03.sum()['Averages']# Variable que servira para obtener el porcentaje

start_angle = 0 # El valor inicial del angula será 0
end_angle = 0  # El valor inicial del angula será 0
while index <= 10:
    
    
    # Obtenemos el promedio
    part = group03.iloc[index]['Averages']
 
    # Obtenemos el porcentaje de su promedio
    percentage = getPercentage(total, part)

    # Obtenemos el valor en radianes
    end_angle += getAngle(percentage)

    # Leyenda
    legend = ("%s - %.2f " %(str(group03['Region Name'][index]), percentage))
    legend += " %"

    # Agregamos un wedge
    figure05.wedge(x=[500], y=[500], radius=300, start_angle=start_angle,
           end_angle=end_angle, radius_units="screen", color=colors01[index], legend=legend, direction="anticlock")
    
    
    
    
    
    # El angulo final de este wedge será el inicio del siguiente
    start_angle=end_angle

    # Aumentamos el contador
    index+=1

group03
show(figure05)
# Out:
#   <div class="bk-root" id="f3e8d0ef-85fa-4dfd-828a-7ec4a8013a4b" data-root-id="93331"></div>

# %%
from bokeh.io import export_png
export_png(obj=figure01, filename="Figura01.html", height=None, width=None, webdriver=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\util\dependencies.py in detect_phantomjs(version)
#      77     try:
# ---> 78         proc = Popen([phantomjs_path, "--version"], stdout=PIPE, stderr=PIPE)
#      79         proc.wait()
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1177                                          os.fspath(cwd) if cwd is not None else None,
# -> 1178                                          startupinfo)
#    1179             finally:
#
# FileNotFoundError: [WinError 2] El sistema no puede encontrar el archivo especificado
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-116-8385f3f8da4c> in <module>
#       1 from bokeh.io import export_png
# ----> 2 export_png(obj=figure01, filename="Figura01.html", height=None, width=None, webdriver=None)
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\io\export.py in export_png(obj, filename, height, width, webdriver)
#      89     '''
#      90
# ---> 91     image = get_screenshot_as_png(obj, height=height, width=width, driver=webdriver)
#      92
#      93     if filename is None:
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\io\export.py in get_screenshot_as_png(obj, driver, **kwargs)
#     199             file.write(decode_utf8(html))
#     200
# --> 201         web_driver = driver if driver is not None else webdriver_control.get()
#     202
#     203         web_driver.get("file:///" + tmp.path)
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\io\webdriver.py in get(self)
#      96             if self.current is not None:
#      97                 terminate_webdriver(self.current)
# ---> 98             self.current = self.create()
#      99         return self.current
#     100
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\io\webdriver.py in create(self)
#     101     def create(self):
#     102         if self.kind == "phantomjs":
# --> 103             return create_phantomjs_webdriver()
#     104         raise ValueError("Unknown webdriver kind %r" % self.kind)
#     105
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\io\webdriver.py in create_phantomjs_webdriver()
#      59                                     '("conda install -c bokeh selenium" or "pip install selenium")')
#      60
# ---> 61         phantomjs_path = detect_phantomjs()
#      62         return webdriver.PhantomJS(executable_path=phantomjs_path, service_log_path=devnull)
#      63
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\util\dependencies.py in detect_phantomjs(version)
#      90     except OSError:
#      91         raise RuntimeError('PhantomJS is not present in PATH or BOKEH_PHANTOMJS_PATH. Try "conda install phantomjs" or \
# ---> 92             "npm install -g phantomjs-prebuilt"')
#      93
#      94     return phantomjs_path
#
# RuntimeError: PhantomJS is not present in PATH or BOKEH_PHANTOMJS_PATH. Try "conda install phantomjs" or             "npm install -g phantomjs-prebuilt"
