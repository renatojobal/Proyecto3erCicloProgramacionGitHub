# %%
# Ejecutamos los notebooks de cada figura
# %run Figure01.ipynb
# %run Figure02.ipynb
# %run Figure03.ipynb
# %run Figure04.ipynb
# %run Figure05.ipynb
# %run Figure06.ipynb
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a6599c46-30e9-4763-916c-63e8b8b27b6a" data-root-id="1003"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1085">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c72f5480-5ec8-4b87-afd2-fa7a2a749d13" data-root-id="1087"></div>
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\io\saving.py:127: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# ...

# %%
# Out:
#   <div class="bk-root" id="dc57ac3c-ff51-445c-800e-2ef9befe9474" data-root-id="9682"></div>

# %%
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17786">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8d36a918-89c0-4f1c-8986-4f931a21230e" data-root-id="17790"></div>
