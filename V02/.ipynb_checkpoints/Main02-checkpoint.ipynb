# %%
# Ejecutamos los notebooks de cada figura
# %run Figure01.ipynb
# %run Figure02.ipynb
# %run Figure03.ipynb
# %run Figure04.ipynb
# %run Figure05.ipynb
# %run Figure06.ipynb
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6970">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bba04d2e-7b05-4ee2-9ca3-f38bf3c84ce4" data-root-id="6972"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7319">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------
# RuntimeError            Traceback (most recent call last)
# ~\OneDrive - Universidad Técnica Particular de Loja - UTPL\Componentes_03\Programacion_De_Algoritmos\Repositorios_03\Proyecto3erCicloProgramacionGitHub\V02\Figure01.ipynb in <module>
#      19
#      20
# ---> 21 figure01.vbar(source=source, x='Region Name', top='Averages', width=0.9, line_color=colors01[2], line_width=2, fill_color=colors01[:12])
#      22 figure01.y_range.start = 0
#      23 figure01.yaxis.axis_label = "Number of children"
#
# fakesource in vbar(self, x, width, top, bottom, **kwargs)
#
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\plotting\helpers.py in func(self, **kwargs)
#     796         incompatible_literal_spec_values += _process_sequence_literals(glyphclass, glyph_ca, source, is_user_source)
#     797         if incompatible_literal_spec_values:
# --> 798             raise RuntimeError(_GLYPH_SOURCE_MSG % nice_join(incompatible_literal_spec_values, conjuction="and"))
#     799
#     800         # handle the nonselection glyph, we always set one
#
# RuntimeError:
#
# Expected fill_color to reference fields in the supplied data source.
#
# When a 'source' argument is passed to a glyph method, values that are sequences
# (like lists or arrays) must come from references to data columns in the source.
#
# For instance, as an example:
#
#     source = ColumnDataSource(data=dict(x=a_list, y=an_array))
#
#     p.circle(x='x', y='y', source=source, ...) # pass column names and a source
#
# Alternatively, *all* data sequences may be provided as literals as long as a
# source is *not* provided:
#
#     p.circle(x=a_list, y=an_array, ...)  # pass actual sequences and no source
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7343">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8ee9b2bb-113e-47d5-b71f-6d0ffdf4588d" data-root-id="7345"></div>
#   <div class="bk-root" id="74399245-109e-4206-a32c-b1ecf56fd50c" data-root-id="7739"></div>
#   <div class="bk-root" id="dd105d6d-da59-478f-977c-c2392a3c06bd" data-root-id="8142"></div>
#   <div class="bk-root" id="61aac63d-3e01-4e66-a639-c0cb2aaabc24" data-root-id="8554"></div>
#   <div class="bk-root" id="63f84587-c40d-4636-9afe-33edfb63fd9d" data-root-id="8975"></div>
#   <div class="bk-root" id="010f5490-3baf-41ed-88f4-d5222a21130f" data-root-id="9405"></div>
#   <div class="bk-root" id="d4889acf-9c44-4952-b8a0-308a51af10f8" data-root-id="9844"></div>
#   <div class="bk-root" id="dea4b429-abde-4719-a3d1-78bbc3d78873" data-root-id="10292"></div>
#   <div class="bk-root" id="e2501840-21b7-434e-a8fb-b1d353efd968" data-root-id="10749"></div>
#   <div class="bk-root" id="bc1b0951-2a97-4845-8057-8d062d3f9918" data-root-id="11215"></div>
#   <div class="bk-root" id="db679ca4-0d99-4b44-93ec-833e447f7095" data-root-id="11690"></div>
#   <div class="bk-root" id="b2f103cd-6c11-42c5-bf27-eb14f56c066b" data-root-id="12174"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="12666">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6be73c65-d41c-43f1-b42f-24dc22c28c0d" data-root-id="12667"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="14304">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="08e14eb9-2b1c-4bc6-9e3a-b2a7ad546cfa" data-root-id="14305"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="15433">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6869bdbe-9031-4132-a6eb-842d8e7242f9" data-root-id="15436"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="15978">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b0e05932-2937-4833-91af-ffd986b5e7e7" data-root-id="15981"></div>

# %%
from bokeh.plotting import figure, show, output_file, output_notebook
from bokeh.models import ColumnDataSource, ColorBar
from bokeh.palettes import Spectral6
from bokeh.transform import linear_cmap

output_notebook()

x = [1,2,3,4,5,7,8,9,10]
y = [1,2,3,4,5,7,8,9,10]

#Use the field name of the column source
mapper = linear_cmap(field_name='y', palette=Spectral6 ,low=min(y) ,high=max(y))

source = ColumnDataSource(dict(x=x,y=y))

p = figure(plot_width=300, plot_height=300, title="Linear Color Map Based on Y")

p.circle(x='x', y='y', line_color=mapper,color=mapper, fill_alpha=1, size=12, source=source)

color_bar = ColorBar(color_mapper=mapper['transform'], width=8,  location=(0,0))

p.add_layout(color_bar, 'right')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17786">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8d36a918-89c0-4f1c-8986-4f931a21230e" data-root-id="17790"></div>
