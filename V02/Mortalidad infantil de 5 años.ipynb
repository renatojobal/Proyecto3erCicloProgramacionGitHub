# %% [markdown]
# <img src="institucional.jpg" alt="logoUtpl">

# %% [markdown]
# # Mortalidad infantil de menores de 5 años

# %% [markdown]
# La tasa de mortalidad infantil en menores de cinco años es un indicador del bienstar de una región. Actualmente estos datos son recogidos por varias origanizaciones no gubernamentales para mayor fidelidad de los datos.
#
#
# En este caso específico analizaremos los datos obtenidos por UNICEF [1]. Los datos recogidos son desde el año 1990 hasta el 2016, utlizando tres niveles incertidumbre

# %% [markdown]
# ### Tasa de mortalidad en menores de 5 años
# La tasa de mortalidad en menores de 5 años es un indicador estadístico de la probabilidad de que un niño fallezca entre su nacimiento y los 5 años de edad. Se expresa en 1 por mil (‰), es decir, en la décima parte de un porcentaje (1% = 0,1 ‰). De este modo es un promedio que indica, por ejemplo, que por cada 1.000 nacimientos en una región, 121 niños fallecen antes de los 5 años de edad.
#
# La mortalidad que ocurre antes de cumplir los cinco años de vida, ha sido asociada con las condiciones de bienestar de la población, principalmente con la prestación de servicios prenatales y de atención al parto, así como a factores relacionados con el control de las enfermedades, la interacción con el medio ambiente y el desarrollo tecnológico. Esta estrecha relación
# se deriva del hecho que, durante las primeras edades, la salud del niño es vulnerable a la acción de factores patológicos de la madre y del medio ambiente que lo rodean, los cuales se minimizan o agudizan de acuerdo con el nivel social y cultural de la familia.[2]

# %% [markdown]
# Los datos que proporciona UNICEF son de libre acceso y se pueden encontrar en su página https://data.unicef.org/.

# %%
# %run Read.ipynb
group
# Out:
#                         Region Name      1990.5      1991.5      1992.5  \
# 0             East Asia and Pacific   57.100000   55.933333   54.466667
# 1   Eastern Europe and Central Asia   46.766667   46.366667   46.300000
# 2       Eastern and Southern Africa  164.266667  162.533333  160.733333
# 3           Europe and Central Asia   31.000000   30.333333   29.833333
# 4       Latin America and Caribbean   55.333333   53.000000   50.633333
# 5      Middle East and North Africa   65.566667   62.733333   60.133333
# 6                     North America   10.966667   10.600000   10.266667
# 7                        South Asia  129.466667  125.733333  122.133333
# 8                Sub-Saharan Africa  180.833333  179.233333  177.666667
# 9           West and Central Africa  198.866667  197.433333  196.033333
# 10                   Western Europe   10.500000   10.033333    9.533333
# 11                            World   93.466667   92.166667   90.933333
#
# ...

# %%
# %run Figure01.ipynb # Presentamos la figura 1
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e0694e84-b86b-4815-bec7-94adab8cad7b" data-root-id="1003"></div>

# %% [markdown]
# Como podemos obserbar en la figura anterior, la region Oeste y Central de África es la que tiene un promedio mayor en la tasa de muertes desde el año 1990 hasta el 2016. En segundo lugar está la región África Subsahariana (paises que no limitan con el mar mediterraneo).
# La región con menor tasa de muertes en menores de 5 años es Europa Occidental.

# %% [markdown]
# A continuación mostramos la tasa de muertes de cada región desde el año 1990 hasta 2016:

# %%
# %run figure02.ipynb
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1085">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ebebf6a0-9fea-4d7f-866e-be38527ee17a" data-root-id="1087"></div>
# c:\users\renat\appdata\local\programs\python\python37-32\lib\site-packages\bokeh\io\saving.py:127: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
#   <div class="bk-root" id="f240a53e-cff1-4e3b-b742-269a976ff45a" data-root-id="1278"></div>
#   <div class="bk-root" id="c756761b-51ba-48a2-aad1-40f4e56a8215" data-root-id="1478"></div>
#   <div class="bk-root" id="46bf1079-455e-454f-ae33-6ca455247b7a" data-root-id="1687"></div>
# ...

# %% [markdown]
# Observamos graficamente que todas las regiones del mundo han ido disminuyendo paulatinamente su tasa de mortalidad en menores de 5 años lo cuál coadyuva al mejoramiento de la calidad de vida de los habitantes. Para observar mejor en perspectiva presentamos un gráfico mulitlineal con todas las regiones.

# %% [markdown]
# La gráfica sigiente muestra la mortalidad en menores de cinco años en perspectiva. Demostrando como regiones como Europa Occidental y Norte America mantienen sus niveles bajos, mientras que la region de Oeste y Central de Africa, si bien ha ido disminuyendo sus indices, aún tiene mucha distancia para igualar a estas otras regiones.

# %%
# %run figure03.ipynb
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3972">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3963aab9-2cd0-4af3-8bd1-f0366b9f70d5" data-root-id="3974"></div>

# %% [markdown]
# El siguiente gráfico representa el promedio de la tasa de muertes de menores de 5 años desde 1990 hasta 2016:

# %%
# %run Figure04.ipynb
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5321">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2b6b5f3a-723c-4a35-9b9a-a932ef8a10a2" data-root-id="5323"></div>

# %% [markdown]
# ##### Comparando la tasa de mortalidad en menores de 5 años 1990-2016

# %%
# %run Figure05.ipynb
# %run Figure06.ipynb
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6179">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c6ede4fd-579c-47c3-9660-25bc4d2f48fe" data-root-id="6182"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6517">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9cf048dd-8b81-48b4-bb0b-8cd8abe09ea7" data-root-id="6520"></div>

# %% [markdown]
# ## Bibliografía
# 1. https://data.unicef.org/topic/child-survival/under-five-mortality/
# 2. https://www.dane.gov.co/files/investigaciones/poblacion/vitales/Bol_TMI_DCD_2014.pdf

# %% [markdown]
#                                                                                             Renato Balcazar, 02/02/2019
